# %%
pip install chromadb
# Out:
# 146.18s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached chromadb-0.4.24-py3-none-any.whl (525 kB)
# ...
#   Using cached build-1.1.1-py3-none-any.whl (19 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 kB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 11.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import chromadb
chroma_client = chromadb.HttpClient(host='localhost', port=8000)
collection = chroma_client.get_or_create_collection(name="my_collection2")
collection.add(
    documents=["This is a document about animals", "This is another document about planets"],
    metadatas=[{"source": "my_source"}, {"source": "my_source"}],
    ids=["id1", "id2"]
)
results = collection.query(
    query_texts=["This is a query document for learning about the elephant "],
    n_results=1
)
print(results)
results = collection.query(
    query_texts=["This is a query document for learning about the sun "],
    n_results=1
)
print(results)
# Out:
# {'ids': [['id1']], 'distances': [[0.7582704985716727]], 'embeddings': None, 'metadatas': [[{'source': 'my_source'}]], 'documents': [['This is a document about animals']], 'uris': None, 'data': None}
# {'ids': [['id2']], 'distances': [[0.847618419018061]], 'embeddings': None, 'metadatas': [[{'source': 'my_source'}]], 'documents': [['This is another document about planets']], 'uris': None, 'data': None}

# %%
import chromadb
chroma_client = chromadb.HttpClient(host='localhost', port=8000)
collection = chroma_client.get_or_create_collection(name="my_collection2")

results = collection.query(
    query_texts=["This is a query document for learning about saturn "],
    n_results=1
)
print(results)
results = collection.query(
    query_texts=["This is a query document for learning about dog "],
    n_results=1
)
print(results)
# Out:
# {'ids': [['id2']], 'distances': [[0.7858796993680268]], 'embeddings': None, 'metadatas': [[{'source': 'my_source'}]], 'documents': [['This is another document about planets']], 'uris': None, 'data': None}
# {'ids': [['id1']], 'distances': [[0.6784089969024063]], 'embeddings': None, 'metadatas': [[{'source': 'my_source'}]], 'documents': [['This is a document about animals']], 'uris': None, 'data': None}
